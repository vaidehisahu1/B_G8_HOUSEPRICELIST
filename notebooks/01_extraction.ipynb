# %% [markdown]
# # Data Extraction
# This notebook focuses on extracting the raw US house price data and performing initial exploration.

# %%
import pandas as pd
import os

# %% [markdown]
# ## Load the Data

# %%
# Define the path to the raw data file
raw_data_path = '../data/raw/US houuse price of 10 states.csv'

# Import the raw dataset
df = pd.read_csv(raw_data_path)

print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %% [markdown]
# ## Initial Data Exploration
# Extracting basic info, shape, and the first few rows of the dataset.

# %%
# Check the shape of the dataset (rows, columns)
print(f"Shape of the dataset: {df.shape}")
df.shape
# Out:
# Shape of the dataset: (12075, 10)
# (12075, 10)

# %%
# Get basic information about the dataset (data types, non-null counts)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12075 entries, 0 to 12074
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        12075 non-null  str
#  1   house_size  11107 non-null  str
#  2   bed         11410 non-null  str
#  3   bath        11410 non-null  str
#  4   price       11009 non-null  str
#  5   broker      9569 non-null   str
#  6   street      12075 non-null  str
#  7   city        12075 non-null  str
#  8   state_name  12075 non-null  str
#  9   zip_code    12075 non-null  int64
# dtypes: int64(1), str(9)
# memory usage: 943.5 KB

# %%
# Display the first 5 rows of the dataset
df.head()
# Out:
#            date                  house_size     bed    bath     price  \
# 0  AUG 29, 2024  2,520 sqft (on 0.44 acres)     4bd     4bd  $415,000
# 1  AUG 29, 2024    704 sqft (on 0.33 acres)     2bd     2bd   $58,000
# 2  AUG 29, 2024  1,926 sqft (on 0.45 acres)     3bd     3bd  $375,000
# 3  AUG 29, 2024                  1,132 sqft  Studio  Studio  $190,000
# 4  AUG 29, 2024                  1,205 sqft     3bd     3bd  $233,900
#
#                                  broker                street          city  \
# 0                                   NaN       2004 W  23rd Ct   Panama City
# 1                                   NaN          5390 Webb St    Graceville
# 2               Coldwell Banker Hartung     6761 Landover Cir   Tallahassee
# 3                       EXP Realty, LLC  1701 S  Fairfield Dr   Perdido Key
# 4  D R Horton Realty of NW Florida, LLC      6274 June Bug Dr        Milton
#
#   state_name  zip_code
# 0    Florida     32405
# 1    Florida     32440
# ...
